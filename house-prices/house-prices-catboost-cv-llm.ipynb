# %%
import pandas as pd
# from catboost import CatBoostRegressor, Pool, cv
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim
from sentence_transformers.quantization import quantize_embeddings
from tqdm import tqdm

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

from catboost import CatBoostRegressor, Pool, cv

import json
# Read the JSON file we just created
with open('extracted_data_description.json', 'r') as file:
    data_desc_dict = json.load(file)

# json_loaded_data

# %%
def prepare_dataset(df):
    # For categorical features, replace NA with "Missing"
    categorical_columns = df.select_dtypes(include=['object']).columns
    for key in categorical_columns:
        df[key] = df[key].astype('category').cat.add_categories("Missing").fillna("Missing")
    categorical_columns = df.select_dtypes(include=['category']).columns
    return df, categorical_columns


def get_text_dataset(dataset_df, data_desc_dict):
    dataset_df_copy = pd.DataFrame()
    for col in dataset_df.columns:
        if col in data_desc_dict:
            # print(col)
            if data_desc_dict[col]['type'] == "Numeric":
                dataset_df_copy[col] =  dataset_df[col].astype(str)
                dataset_df_copy[col] = dataset_df_copy[col].map(lambda x: data_desc_dict[col]['description'] + ' is ' + x)
            elif data_desc_dict[col]['type'] == "Categorical":
                dataset_df_copy[col] = (dataset_df[col].astype(str)).map(data_desc_dict[col]['values'])
                # fill na with missing
                dataset_df_copy[col] = dataset_df_copy[col].fillna("Missing")
                dataset_df_copy[col] = dataset_df_copy[col].map(lambda x: data_desc_dict[col]['description'] + ' is ' + x)
            else:
                raise ValueError("Unknown type: {}".format(data_desc_dict[col]['type']))
    return dataset_df_copy
            
def get_text_embeddings(dataset_df_text, embedding_model):

    dataset_df_embedding = pd.DataFrame()
    bad_columns = []
    embeddings_dict = {}
    print("embedding columns")
    for col in tqdm(dataset_df_text.columns):
        try:
            unique_values = dataset_df_text[col].unique()
            unique_values_embeddings = {x: embedding_model.encode(x) for x in unique_values}
            dataset_df_embedding[col] = dataset_df_text[col].map(unique_values_embeddings)
            embeddings_dict[col] = unique_values_embeddings
        except:
            bad_columns.append(col)
    print("Skip embedding on these columns: {}".format(bad_columns))

    return dataset_df_embedding, embeddings_dict

class EmbeddingPCA():
    def __init__(self):
        self.pca_model = {}
        self.scalar_model = {}
    
    def fit_transform(self, embeddings_dict, dimensions = 1):
        new_embeddings_dict = {}
        for col in embeddings_dict:
            self.scalar_model[col] = StandardScaler()
            self.pca_model[col] = PCA(n_components=dimensions)
            cur_embedding = np.array(list(embeddings_dict[col].values()))
            cur_embedding_standardize = self.scalar_model[col].fit_transform(cur_embedding)
            cur_embedding_reduce = self.pca_model[col].fit_transform(cur_embedding_standardize)
            new_embeddings_dict[col] = {k: v[0] for k, v in zip(embeddings_dict[col].keys(), cur_embedding_reduce)}
        return new_embeddings_dict
    
    def transform(self, embeddings_dict):
        # if not fit, raise error
        if self.pca_model == {}:
            raise ValueError("PCA model not fitted")
        else:
            new_embeddings_dict = {}
            for col in embeddings_dict:
                cur_embedding = np.array(list(embeddings_dict[col].values()))
                cur_embedding_standardize = self.scalar_model[col].transform(cur_embedding)
                cur_embedding_reduce = self.pca_model[col].transform(cur_embedding_standardize)
                new_embeddings_dict[col] = {k: v[0] for k, v in zip(embeddings_dict[col].keys(), cur_embedding_reduce)}
            return new_embeddings_dict


    
def get_pca_embedding(dataset_df_text, pca_embeddings_dict):
    dataset_df_pca_embedding = pd.DataFrame()
    for col in dataset_df_text.columns:
        dataset_df_pca_embedding[col + '_' + 'emb'] = dataset_df_text[col].map(pca_embeddings_dict[col])
    return dataset_df_pca_embedding

# %%
train_file_path = "../data/house-prices/train.csv"
dataset_df = pd.read_csv(train_file_path)
print("Full train dataset shape is {}".format(dataset_df.shape))
dataset_df.head(3)

target_column = 'SalePrice'
y = dataset_df.pop(target_column)
X = dataset_df.drop('Id', axis=1)
# Out:
# Full train dataset shape is (1460, 81)

# %%
dataset_df_text = get_text_dataset(X, data_desc_dict)
dataset_df_text.head(2)
# Out:
#                                           MSSubClass  \
# 0  Identifies the type of dwelling involved in th...
# 1  Identifies the type of dwelling involved in th...
#
#                                             MSZoning  \
# 0  Identifies the general zoning classification o...
# 1  Identifies the general zoning classification o...
#
#                                          LotFrontage  \
# 0  Linear feet of street connected to property is...
# 1  Linear feet of street connected to property is...
#
#                            LotArea                                    Street  \
# 0  Lot size in square feet is 8450  Type of road access to property is Paved
# 1  Lot size in square feet is 9600  Type of road access to property is Paved
#
#                                          Alley  \
# 0  Type of alley access to property is Missing
# 1  Type of alley access to property is Missing
#
#                                LotShape  \
# 0  General shape of property is Regular
# 1  General shape of property is Regular
#
#                                    LandContour  \
# 0  Flatness of the property is Near Flat/Level
# 1  Flatness of the property is Near Flat/Level
#
#                                            Utilities  \
# 0  Type of utilities available is All public Util...
# 1  Type of utilities available is All public Util...
#
#                                            LotConfig  ...  \
# 0                    Lot configuration is Inside lot  ...
# 1  Lot configuration is Frontage on 2 sides of pr...  ...
#
#                              ScreenPorch                       PoolArea  \
# 0  Screen porch area in square feet is 0  Pool area in square feet is 0
# 1  Screen porch area in square feet is 0  Pool area in square feet is 0
#
#                     PoolQC                     Fence  \
# 0  Pool quality is Missing  Fence quality is Missing
# 1  Pool quality is Missing  Fence quality is Missing
#
#                                          MiscFeature  \
# 0  Miscellaneous feature not covered in other cat...
# 1  Miscellaneous feature not covered in other cat...
#
#                                 MiscVal                MoSold  \
# 0  $Value of miscellaneous feature is 0  Month Sold (MM) is 2
# 1  $Value of miscellaneous feature is 0  Month Sold (MM) is 5
#
#                      YrSold                                      SaleType  \
# 0  Year Sold (YYYY) is 2008  Type of sale is Warranty Deed - Conventional
# 1  Year Sold (YYYY) is 2007  Type of sale is Warranty Deed - Conventional
#
#                       SaleCondition
# 0  Condition of sale is Normal Sale
# 1  Condition of sale is Normal Sale
#
# [2 rows x 77 columns]

# %%
dimensions = 512
text_model = SentenceTransformer("mixedbread-ai/mxbai-embed-large-v1", truncate_dim=dimensions)
dataset_df_embedding, embeddings_dict  = get_text_embeddings(dataset_df_text, text_model)
# Out:
# embedding columns
# 100%|██████████| 77/77 [02:15<00:00,  1.76s/it]
# Skip embedding on these columns: []

# %%
embedding_pca = EmbeddingPCA()
pca_embeddings_dict = embedding_pca.fit_transform(embeddings_dict)
X_emb = get_pca_embedding(dataset_df_text, pca_embeddings_dict)

X_new = pd.concat([X, X_emb], axis=1)

# %%
X_train, categorical_columns = prepare_dataset(pd.concat([X, X_emb], axis=1))
X_train[categorical_columns].head(10)
# Out:
#   MSZoning Street    Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave  Missing      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave  Missing      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave  Missing      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave  Missing      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave  Missing      IR1         Lvl    AllPub       FR2       Gtl
# 5       RL   Pave  Missing      IR1         Lvl    AllPub    Inside       Gtl
# 6       RL   Pave  Missing      Reg         Lvl    AllPub    Inside       Gtl
# 7       RL   Pave  Missing      IR1         Lvl    AllPub    Corner       Gtl
# 8       RM   Pave  Missing      Reg         Lvl    AllPub    Inside       Gtl
# 9       RL   Pave  Missing      Reg         Lvl    AllPub    Corner       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
# 5      Mitchel       Norm  ...     Attchd          Unf         TA         TA
# 6      Somerst       Norm  ...     Attchd          RFn         TA         TA
# 7       NWAmes       PosN  ...     Attchd          RFn         TA         TA
# 8      OldTown     Artery  ...     Detchd          Unf         Fa         TA
# 9      BrkSide     Artery  ...     Attchd          RFn         Gd         TA
#
#   PavedDrive   PoolQC    Fence MiscFeature SaleType SaleCondition
# 0          Y  Missing  Missing     Missing       WD        Normal
# 1          Y  Missing  Missing     Missing       WD        Normal
# 2          Y  Missing  Missing     Missing       WD        Normal
# 3          Y  Missing  Missing     Missing       WD       Abnorml
# 4          Y  Missing  Missing     Missing       WD        Normal
# 5          Y  Missing    MnPrv        Shed       WD        Normal
# 6          Y  Missing  Missing     Missing       WD        Normal
# 7          Y  Missing  Missing        Shed       WD        Normal
# 8          Y  Missing  Missing     Missing       WD       Abnorml
# 9          Y  Missing  Missing     Missing       WD        Normal
#
# [10 rows x 43 columns]

# %%
# Prepare dataset
# target_column = 'SalePrice'
# y = dataset_df.pop(target_column)
# X = dataset_df.drop('Id', axis=1)

# %%
# # Define model parameters
# params = {
#     'iterations': 1000,
#     'depth': 6,
#     'loss_function': 'RMSE',
#     'verbose': 200,
#     'early_stopping_rounds': 50
# }

# # Cross-validation parameters
# cv_params = {
#     'fold_count': 5,     # Number of folds in CV
#     'shuffle': True,     # Shuffle data before splitting into batches
#     'partition_random_seed': 0,  # Random seed for shuffling
#     'stratified': False,  # Whether to perform stratified sampling
#     'plot': True         # Whether to plot curve of metrics during training
# }

# %%
# # Perform cross-validation
# pool_data = Pool(data=X, label=y, cat_features=categorical_columns.to_list())
# cv_results = cv(pool=pool_data, params=params, fold_count=cv_params['fold_count'],
#                 shuffle=cv_params['shuffle'], partition_random_seed=cv_params['partition_random_seed'],
#                 stratified=cv_params['stratified'], plot=cv_params['plot'])

# # Output results
# print(cv_results)

# %%
# # Grid Search
# from sklearn.model_selection import GridSearchCV

# # Define the model
# model = CatBoostRegressor()

# # Set up the parameter grid
# param_grid = {
#     'depth': [4, 6, 8, 10],
#     'learning_rate': [0.01, 0.03, 0.05, 0.1],
#     'iterations': [2000]
# }

# # Configure GridSearchCV
# # When cv=None, default is 5-fold cross validation
# grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
#                            cv=None, scoring='neg_mean_squared_error', verbose=2)

# # Fit GridSearchCV
# grid_search.fit(X, y, cat_features=categorical_columns.to_list(), verbose=200)

# # Best parameters and best score
# print("Best parameters:", grid_search.best_params_)
# print("Best RMSE:", (-grid_search.best_score_) ** 0.5)

# %%
# Initialize CatBoostRegressor
model = CatBoostRegressor(
    cat_features=categorical_columns.to_list(),
    verbose=200,
    depth=6,
    iterations=30000,
    # iterations=300,
    learning_rate=0.03,
)

# Train the model
model.fit(X_train, y)
# Out:
# 0:	learn: 77838.1862318	total: 111ms	remaining: 55m 41s
# 200:	learn: 19250.8946561	total: 15.8s	remaining: 39m 8s
# 400:	learn: 15123.7771654	total: 30.1s	remaining: 37m 4s
# 600:	learn: 12567.2579072	total: 44.7s	remaining: 36m 27s
# 800:	learn: 10494.0051396	total: 1m 1s	remaining: 37m 39s
# 1000:	learn: 8993.8069509	total: 1m 19s	remaining: 38m 19s
# 1200:	learn: 7826.6188478	total: 1m 36s	remaining: 38m 37s
# 1400:	learn: 6864.1057234	total: 1m 53s	remaining: 38m 37s
# 1600:	learn: 6160.3044644	total: 2m 10s	remaining: 38m 32s
# 1800:	learn: 5513.0450970	total: 2m 25s	remaining: 37m 55s
# 2000:	learn: 4971.2665789	total: 2m 41s	remaining: 37m 40s
# 2200:	learn: 4544.8476530	total: 2m 58s	remaining: 37m 40s
# 2400:	learn: 4140.0636278	total: 3m 15s	remaining: 37m 24s
# 2600:	learn: 3771.3473153	total: 3m 32s	remaining: 37m 18s
# 2800:	learn: 3446.8791492	total: 3m 48s	remaining: 37m 1s
# 3000:	learn: 3167.8855682	total: 4m 4s	remaining: 36m 44s
# 3200:	learn: 2925.4862845	total: 4m 21s	remaining: 36m 30s
# 3400:	learn: 2709.4002258	total: 4m 39s	remaining: 36m 29s
# 3600:	learn: 2487.4838158	total: 4m 56s	remaining: 36m 11s
# 3800:	learn: 2293.2067364	total: 5m 12s	remaining: 35m 56s
# 4000:	learn: 2119.6135335	total: 5m 29s	remaining: 35m 42s
# 4200:	learn: 1981.2111441	total: 5m 46s	remaining: 35m 26s
# 4400:	learn: 1840.1590624	total: 6m 3s	remaining: 35m 12s
# 4600:	learn: 1712.0516692	total: 6m 21s	remaining: 35m 3s
# 4800:	learn: 1601.8727713	total: 6m 37s	remaining: 34m 45s
# 5000:	learn: 1503.7368337	total: 6m 55s	remaining: 34m 36s
# 5200:	learn: 1407.4577050	total: 7m 13s	remaining: 34m 27s
# 5400:	learn: 1316.5340035	total: 7m 31s	remaining: 34m 17s
# 5600:	learn: 1241.3508140	total: 7m 49s	remaining: 34m 4s
# 5800:	learn: 1169.5846709	total: 8m 6s	remaining: 33m 48s
# 6000:	learn: 1108.7399391	total: 8m 21s	remaining: 33m 24s
# 6200:	learn: 1040.0217647	total: 8m 36s	remaining: 33m 2s
# 6400:	learn: 987.3129137	total: 8m 52s	remaining: 32m 42s
# 6600:	learn: 938.3501947	total: 9m 7s	remaining: 32m 21s
# 6800:	learn: 891.2437842	total: 9m 20s	remaining: 31m 52s
# 7000:	learn: 844.9671005	total: 9m 33s	remaining: 31m 23s
# 7200:	learn: 805.4228041	total: 9m 46s	remaining: 30m 55s
# 7400:	learn: 763.8175349	total: 9m 59s	remaining: 30m 30s
# 7600:	learn: 726.5523599	total: 10m 14s	remaining: 30m 12s
# 7800:	learn: 690.3246096	total: 10m 30s	remaining: 29m 55s
# 8000:	learn: 658.4884376	total: 10m 46s	remaining: 29m 38s
# 8200:	learn: 628.9980861	total: 11m 3s	remaining: 29m 22s
# 8400:	learn: 601.9302465	total: 11m 18s	remaining: 29m 5s
# 8600:	learn: 574.6610507	total: 11m 33s	remaining: 28m 45s
# 8800:	learn: 549.3793698	total: 11m 49s	remaining: 28m 27s
# 9000:	learn: 525.5107553	total: 12m 4s	remaining: 28m 10s
# 9200:	learn: 501.3037975	total: 12m 20s	remaining: 27m 53s
# 9400:	learn: 477.6860660	total: 12m 35s	remaining: 27m 36s
# 9600:	learn: 457.2417322	total: 12m 52s	remaining: 27m 21s
# 9800:	learn: 436.9878790	total: 13m 8s	remaining: 27m 5s
# 10000:	learn: 419.6917481	total: 13m 25s	remaining: 26m 50s
# 10200:	learn: 402.3687822	total: 13m 40s	remaining: 26m 32s
# 10400:	learn: 386.3468937	total: 13m 56s	remaining: 26m 16s
# 10600:	learn: 373.0036980	total: 14m 12s	remaining: 26m
# 10800:	learn: 358.1507048	total: 14m 28s	remaining: 25m 44s
# 11000:	learn: 343.2280181	total: 14m 46s	remaining: 25m 30s
# 11200:	learn: 330.2654700	total: 15m 3s	remaining: 25m 15s
# 11400:	learn: 317.9099727	total: 15m 19s	remaining: 24m 59s
# 11600:	learn: 306.7537792	total: 15m 35s	remaining: 24m 43s
# 11800:	learn: 296.3545392	total: 15m 52s	remaining: 24m 28s
# 12000:	learn: 285.9745725	total: 16m 8s	remaining: 24m 12s
# 12200:	learn: 274.9967378	total: 16m 24s	remaining: 23m 56s
# 12400:	learn: 264.9030360	total: 16m 40s	remaining: 23m 39s
# 12600:	learn: 254.9903649	total: 16m 56s	remaining: 23m 23s
# 12800:	learn: 245.2444677	total: 17m 13s	remaining: 23m 8s
# 13000:	learn: 236.8354488	total: 17m 29s	remaining: 22m 52s
# 13200:	learn: 228.7413995	total: 17m 45s	remaining: 22m 35s
# 13400:	learn: 220.2407513	total: 18m 1s	remaining: 22m 19s
# 13600:	learn: 212.5311898	total: 18m 17s	remaining: 22m 2s
# 13800:	learn: 205.6210887	total: 18m 33s	remaining: 21m 46s
# 14000:	learn: 198.7001709	total: 18m 48s	remaining: 21m 29s
# 14200:	learn: 192.2163863	total: 19m 2s	remaining: 21m 11s
# 14400:	learn: 185.9050009	total: 19m 19s	remaining: 20m 55s
# 14600:	learn: 180.0398667	total: 19m 35s	remaining: 20m 40s
# 14800:	learn: 173.7126660	total: 19m 52s	remaining: 20m 24s
# 15000:	learn: 168.0604103	total: 20m 7s	remaining: 20m 7s
# 15200:	learn: 162.6711467	total: 20m 24s	remaining: 19m 52s
# 15400:	learn: 157.7413012	total: 20m 40s	remaining: 19m 35s
# 15600:	learn: 151.7501047	total: 20m 57s	remaining: 19m 20s
# 15800:	learn: 146.6909046	total: 21m 14s	remaining: 19m 5s
# 16000:	learn: 141.9663815	total: 21m 30s	remaining: 18m 49s
# 16200:	learn: 137.6134149	total: 21m 47s	remaining: 18m 33s
# 16400:	learn: 133.7615111	total: 22m 3s	remaining: 18m 17s
# 16600:	learn: 129.8744601	total: 22m 20s	remaining: 18m 1s
# 16800:	learn: 125.6831750	total: 22m 37s	remaining: 17m 46s
# 17000:	learn: 122.2009567	total: 22m 54s	remaining: 17m 30s
# 17200:	learn: 118.5708550	total: 23m 11s	remaining: 17m 15s
# 17400:	learn: 114.8204010	total: 23m 28s	remaining: 16m 59s
# 17600:	learn: 111.6146087	total: 23m 45s	remaining: 16m 43s
# 17800:	learn: 108.5265587	total: 24m 1s	remaining: 16m 27s
# 18000:	learn: 105.3270360	total: 24m 16s	remaining: 16m 10s
# 18200:	learn: 102.3533241	total: 24m 32s	remaining: 15m 54s
# 18400:	learn: 98.7599762	total: 24m 47s	remaining: 15m 37s
# 18600:	learn: 96.4398327	total: 25m 3s	remaining: 15m 21s
# 18800:	learn: 93.4321096	total: 25m 18s	remaining: 15m 4s
# 19000:	learn: 90.6854521	total: 25m 33s	remaining: 14m 47s
# 19200:	learn: 88.0788003	total: 25m 48s	remaining: 14m 31s
# 19400:	learn: 85.7895095	total: 26m 3s	remaining: 14m 14s
# 19600:	learn: 83.4820735	total: 26m 20s	remaining: 13m 58s
# 19800:	learn: 81.3024790	total: 26m 34s	remaining: 13m 41s
# 20000:	learn: 79.0868715	total: 26m 50s	remaining: 13m 25s
# 20200:	learn: 76.9586987	total: 27m 6s	remaining: 13m 8s
# 20400:	learn: 74.9029472	total: 27m 19s	remaining: 12m 51s
# 20600:	learn: 72.7568907	total: 27m 32s	remaining: 12m 34s
# 20800:	learn: 70.5871699	total: 27m 44s	remaining: 12m 16s
# 21000:	learn: 68.7434079	total: 28m 3s	remaining: 12m 1s
# 21200:	learn: 66.9950213	total: 28m 29s	remaining: 11m 49s
# 21400:	learn: 65.0899716	total: 28m 56s	remaining: 11m 37s
# 21600:	learn: 63.4568159	total: 29m 23s	remaining: 11m 25s
# 21800:	learn: 61.7695004	total: 29m 49s	remaining: 11m 13s
# 22000:	learn: 60.1438820	total: 30m 6s	remaining: 10m 56s
# 22200:	learn: 58.7256773	total: 30m 18s	remaining: 10m 38s
# 22400:	learn: 57.0952149	total: 30m 30s	remaining: 10m 21s
# 22600:	learn: 55.6812357	total: 30m 44s	remaining: 10m 3s
# 22800:	learn: 54.4413785	total: 30m 58s	remaining: 9m 46s
# 23000:	learn: 52.8751753	total: 31m 12s	remaining: 9m 29s
# 23200:	learn: 51.4991052	total: 31m 27s	remaining: 9m 13s
# 23400:	learn: 50.0214709	total: 31m 41s	remaining: 8m 56s
# 23600:	learn: 48.7952003	total: 31m 55s	remaining: 8m 39s
# 23800:	learn: 47.6391753	total: 32m 9s	remaining: 8m 22s
# 24000:	learn: 46.5284746	total: 32m 23s	remaining: 8m 5s
# 24200:	learn: 45.5834036	total: 32m 38s	remaining: 7m 49s
# 24400:	learn: 44.6643028	total: 32m 52s	remaining: 7m 32s
# 24600:	learn: 43.6236068	total: 33m 6s	remaining: 7m 15s
# 24800:	learn: 42.5717888	total: 33m 20s	remaining: 6m 59s
# 25000:	learn: 41.6170618	total: 33m 35s	remaining: 6m 42s
# 25200:	learn: 40.5594692	total: 33m 49s	remaining: 6m 26s
# 25400:	learn: 39.5802591	total: 34m 3s	remaining: 6m 9s
# 25600:	learn: 38.7099454	total: 34m 17s	remaining: 5m 53s
# 25800:	learn: 37.6546702	total: 34m 31s	remaining: 5m 37s
# 26000:	learn: 36.8389726	total: 34m 45s	remaining: 5m 20s
# 26200:	learn: 36.0002267	total: 35m	remaining: 5m 4s
# 26400:	learn: 35.2002464	total: 35m 14s	remaining: 4m 48s
# 26600:	learn: 34.2225323	total: 35m 28s	remaining: 4m 31s
# 26800:	learn: 33.5172097	total: 35m 42s	remaining: 4m 15s
# 27000:	learn: 32.5780825	total: 35m 56s	remaining: 3m 59s
# 27200:	learn: 31.8882087	total: 36m 10s	remaining: 3m 43s
# 27400:	learn: 31.1484106	total: 36m 24s	remaining: 3m 27s
# 27600:	learn: 30.4494270	total: 36m 38s	remaining: 3m 11s
# 27800:	learn: 29.7634953	total: 36m 53s	remaining: 2m 55s
# 28000:	learn: 28.9361532	total: 37m 7s	remaining: 2m 39s
# 28200:	learn: 28.0085631	total: 37m 21s	remaining: 2m 23s
# 28400:	learn: 27.2995283	total: 37m 36s	remaining: 2m 7s
# 28600:	learn: 26.7627478	total: 37m 50s	remaining: 1m 51s
# 28800:	learn: 26.0981190	total: 38m 4s	remaining: 1m 35s
# 29000:	learn: 25.3645006	total: 38m 18s	remaining: 1m 19s
# 29200:	learn: 24.7347798	total: 38m 32s	remaining: 1m 3s
# 29400:	learn: 24.1216071	total: 38m 47s	remaining: 47.4s
# 29600:	learn: 23.5118789	total: 39m 1s	remaining: 31.6s
# 29800:	learn: 22.9077582	total: 39m 15s	remaining: 15.7s
# 29999:	learn: 22.3912211	total: 39m 29s	remaining: 0us

# %%
feature_importances = model.get_feature_importance()
print(pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances}).sort_values(by='Importance', ascending=False))
# Out:
#               Feature  Importance
# 45          GrLivArea   13.652408
# 16        OverallQual   12.922771
# 95    OverallQual_emb    9.621930
# 37        TotalBsmtSF    4.356372
# 137    GarageCars_emb    3.736317
# ..                ...         ...
# 113  BsmtFinType2_emb    0.000230
# 8           Utilities    0.000108
# 4              Street    0.000056
# 87      Utilities_emb    0.000033
# 83         Street_emb    0.000003
#
# [156 rows x 2 columns]

# %%
test_file_path = "../data/house-prices/test.csv"
test_data = pd.read_csv(test_file_path)
ids = test_data.pop('Id')

test_data, _ = prepare_dataset(test_data)
test_data.head(3)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          20       RH         80.0    11622   Pave  Missing      Reg
# 1          20       RL         81.0    14267   Pave  Missing      IR1
# 2          60       RL         74.0    13830   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea   PoolQC    Fence  \
# 0         Lvl    AllPub    Inside  ...         120        0  Missing    MnPrv
# 1         Lvl    AllPub    Corner  ...           0        0  Missing  Missing
# 2         Lvl    AllPub    Inside  ...           0        0  Missing    MnPrv
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0     Missing       0       6    2010        WD         Normal
# 1        Gar2   12500       6    2010        WD         Normal
# 2     Missing       0       3    2010        WD         Normal
#
# [3 rows x 79 columns]

# %%
# get text embedding as well
test_data_text = get_text_dataset(test_data, data_desc_dict)
_, test_embeddings_dict  = get_text_embeddings(test_data_text, text_model)

test_pca_embeddings_dict = embedding_pca.transform(test_embeddings_dict)
X_test_emb = get_pca_embedding(test_data_text, test_pca_embeddings_dict)
X_test = pd.concat([test_data, X_test_emb], axis=1)
X_test.head(3)
# Out:
# embedding columns
#   0%|          | 0/77 [00:00<?, ?it/s]
# 100%|██████████| 77/77 [01:52<00:00,  1.46s/it]
# Skip embedding on these columns: []
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          20       RH         80.0    11622   Pave  Missing      Reg
# 1          20       RL         81.0    14267   Pave  Missing      IR1
# 2          60       RL         74.0    13830   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch_emb PoolArea_emb  \
# 0         Lvl    AllPub    Inside  ...        2.652730    26.343601
# 1         Lvl    AllPub    Corner  ...       -0.670933    26.343601
# 2         Lvl    AllPub    Inside  ...       -0.670933    26.343601
#
#   PoolQC_emb  Fence_emb MiscFeature_emb MiscVal_emb  MoSold_emb  YrSold_emb  \
# 0  24.747883  15.385204      -17.585976   38.915447   -5.000162  -12.179186
# 1  24.747883 -13.560848       -0.837340   -0.449458   -5.000162  -12.179186
# 2  24.747883  15.385204      -17.585976   38.915447   -7.453216  -12.179186
#
#    SaleType_emb  SaleCondition_emb
# 0     15.406698         -14.946821
# 1     15.406698         -14.946821
# 2     15.406698         -14.946821
#
# [3 rows x 156 columns]

# %%
sample_submission_df = pd.read_csv('../data/house-prices/sample_submission.csv')
sample_submission_df['SalePrice'] = model.predict(X_test)
sample_submission_df.to_csv('../working/catboost-cv-rattana.csv', index=False)
sample_submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  120669.143406
# 1  1462  160649.951146
# 2  1463  188243.018352
# 3  1464  187030.209516
# 4  1465  189642.307195
