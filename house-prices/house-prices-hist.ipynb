# %%
# Using HistGradientBoostingRegressor

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
def prepare_dataset(df, one_hot=False):
    # Encode categorical features with one hot, and replace NA with "Missing"
    # With one hot encoding support
    categorical_columns = df.select_dtypes(include=['object']).columns
    for key in categorical_columns:
        df[key] = df[key].astype('category').cat.add_categories("Missing").fillna("Missing")
    if not one_hot:
        return df
    
    categorical_columns = df.select_dtypes(include=['category']).columns
    encoder = OneHotEncoder(sparse_output=False)
    encoded_features = encoder.fit_transform(df[categorical_columns])
    encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_columns.to_list()))
    df = pd.concat([df.drop(categorical_columns, axis=1), encoded_df], axis=1)
    return df

# %%
train_file_path = "data/house-prices/train.csv"
dataset_df = pd.read_csv(train_file_path)
dataset_df = dataset_df.drop('Id', axis=1)
target_column = 'SalePrice'
dataset_df = prepare_dataset(dataset_df, False)
y = dataset_df.pop(target_column)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset_df, y, test_size=0.2, random_state=42)

# %%
# Initialize the HistGradientBoostingRegressor
# Set categorical_features to 'from_dtype' so that it automatically detects pandas.Categorical columns (requires sklearn >= 1.4.2)
model = HistGradientBoostingRegressor(categorical_features='from_dtype')

# Train the model
model.fit(X_train, y_train)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
# HistGradientBoostingRegressor(categorical_features='from_dtype')

# %%
test_file_path = "data/house-prices/test.csv"
test_data = pd.read_csv(test_file_path)
ids = test_data.pop('Id')

test_data = prepare_dataset(test_data, False)
sample_submission_df = pd.read_csv('data/house-prices/sample_submission.csv')
sample_submission_df['SalePrice'] = model.predict(test_data)
sample_submission_df.to_csv('working/hist.csv', index=False)
sample_submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  126861.641863
# 1  1462  153242.213146
# 2  1463  186711.176803
# 3  1464  199130.572734
# 4  1465  188666.519241

# %% [markdown]
# # Cross Validation

# %%
# Grid Search
from sklearn.model_selection import GridSearchCV

# Define the model
model = HistGradientBoostingRegressor(categorical_features='from_dtype')

# Set up the parameter grid
param_grid = {
    'max_depth': [3, 4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.3],
    'max_iter': [100],
    'l2_regularization': [0.1, 1, 2, 3, 5, 10],
}

# Configure GridSearchCV
# When cv=None, default is 5-fold cross validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           cv=None, scoring='neg_mean_squared_error', verbose=2)

# Fit GridSearchCV
grid_search.fit(dataset_df, y)

# Best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best RMSE:", (-grid_search.best_score_) ** 0.5)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.5s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   2.8s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   8.8s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=3, max_iter=100; total time=  11.4s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   8.8s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  14.8s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  16.1s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  15.6s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  14.9s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  12.7s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=6, max_iter=100; total time=  25.4s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=6, max_iter=100; total time=  25.4s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=6, max_iter=100; total time=   6.4s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=6, max_iter=100; total time=  13.8s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=6, max_iter=100; total time=  25.6s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=8, max_iter=100; total time=  35.0s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=8, max_iter=100; total time=  29.6s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=8, max_iter=100; total time=  31.7s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=8, max_iter=100; total time=  33.9s
# [CV] END l2_regularization=0.1, learning_rate=0.05, max_depth=8, max_iter=100; total time=  30.2s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   7.6s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   8.8s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   7.3s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   7.1s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   4.3s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   9.8s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=4, max_iter=100; total time=  11.1s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=4, max_iter=100; total time=  10.7s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   5.5s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=4, max_iter=100; total time=  14.1s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=6, max_iter=100; total time=  18.0s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=6, max_iter=100; total time=  20.1s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=6, max_iter=100; total time=  18.1s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=6, max_iter=100; total time=  17.1s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=6, max_iter=100; total time=  17.4s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=8, max_iter=100; total time=  24.8s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=8, max_iter=100; total time=  23.0s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=8, max_iter=100; total time=  22.9s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=8, max_iter=100; total time=  23.2s
# [CV] END l2_regularization=0.1, learning_rate=0.1, max_depth=8, max_iter=100; total time=  25.1s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   7.3s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   8.1s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   8.0s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   7.1s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   8.7s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=4, max_iter=100; total time=  12.9s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=4, max_iter=100; total time=  10.1s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=4, max_iter=100; total time=  11.5s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=4, max_iter=100; total time=  13.8s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=4, max_iter=100; total time=  11.4s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=6, max_iter=100; total time=  15.2s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=6, max_iter=100; total time=  15.9s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=6, max_iter=100; total time=  21.8s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=6, max_iter=100; total time=  15.4s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=6, max_iter=100; total time=  16.9s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=8, max_iter=100; total time=  22.1s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=8, max_iter=100; total time=  21.3s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=8, max_iter=100; total time=  24.0s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=8, max_iter=100; total time=  21.4s
# [CV] END l2_regularization=0.1, learning_rate=0.3, max_depth=8, max_iter=100; total time=  18.6s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   8.8s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   2.2s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   3.1s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   0.8s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=4, max_iter=100; total time=   9.9s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  13.9s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  11.8s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  15.1s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=4, max_iter=100; total time=  12.5s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=6, max_iter=100; total time=  29.7s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=6, max_iter=100; total time=  18.0s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=6, max_iter=100; total time=   2.8s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=6, max_iter=100; total time=   4.3s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=6, max_iter=100; total time=   3.8s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=8, max_iter=100; total time=   5.7s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=8, max_iter=100; total time=   4.4s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=8, max_iter=100; total time=   5.5s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=8, max_iter=100; total time=   8.0s
# [CV] END l2_regularization=1, learning_rate=0.05, max_depth=8, max_iter=100; total time=   3.5s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.0s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.5s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.0s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   2.0s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.6s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.7s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.9s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.7s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=6, max_iter=100; total time=   3.3s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=6, max_iter=100; total time=   3.7s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=6, max_iter=100; total time=   4.7s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=6, max_iter=100; total time=   4.0s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=6, max_iter=100; total time=   3.5s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=8, max_iter=100; total time=   5.1s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=8, max_iter=100; total time=   5.1s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=8, max_iter=100; total time=   4.9s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=8, max_iter=100; total time=   4.9s
# [CV] END l2_regularization=1, learning_rate=0.1, max_depth=8, max_iter=100; total time=   5.4s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.1s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.8s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.5s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=4, max_iter=100; total time=   1.7s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=4, max_iter=100; total time=   2.4s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=4, max_iter=100; total time=   2.6s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=4, max_iter=100; total time=   1.6s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=6, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=6, max_iter=100; total time=   1.6s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=6, max_iter=100; total time=   3.2s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=6, max_iter=100; total time=   2.8s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=6, max_iter=100; total time=   3.0s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=8, max_iter=100; total time=   4.5s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=8, max_iter=100; total time=   4.0s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=8, max_iter=100; total time=   4.2s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=8, max_iter=100; total time=   4.0s
# [CV] END l2_regularization=1, learning_rate=0.3, max_depth=8, max_iter=100; total time=   2.7s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.0s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=3, max_iter=100; total time=   0.9s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=4, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.1s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.2s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.3s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.1s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=6, max_iter=100; total time=   4.1s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=6, max_iter=100; total time=   5.1s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=6, max_iter=100; total time=   4.5s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=6, max_iter=100; total time=   3.7s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=6, max_iter=100; total time=   2.6s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=8, max_iter=100; total time=   3.9s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=8, max_iter=100; total time=   3.4s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=8, max_iter=100; total time=   4.0s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=8, max_iter=100; total time=   6.1s
# [CV] END l2_regularization=2, learning_rate=0.05, max_depth=8, max_iter=100; total time=   5.9s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.3s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.0s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=3, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.6s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=4, max_iter=100; total time=   0.9s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=4, max_iter=100; total time=   1.8s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=4, max_iter=100; total time=   2.1s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=6, max_iter=100; total time=   1.6s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=6, max_iter=100; total time=   2.0s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=6, max_iter=100; total time=   3.7s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=6, max_iter=100; total time=   3.6s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=6, max_iter=100; total time=   2.2s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=8, max_iter=100; total time=   3.9s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=8, max_iter=100; total time=   4.7s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=8, max_iter=100; total time=   4.0s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=8, max_iter=100; total time=   4.7s
# [CV] END l2_regularization=2, learning_rate=0.1, max_depth=8, max_iter=100; total time=   5.0s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.5s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.9s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=3, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=4, max_iter=100; total time=   2.2s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=4, max_iter=100; total time=   2.3s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=4, max_iter=100; total time=   2.6s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=4, max_iter=100; total time=   2.0s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=4, max_iter=100; total time=   1.8s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=6, max_iter=100; total time=   3.0s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=6, max_iter=100; total time=   1.8s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=6, max_iter=100; total time=   2.6s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=6, max_iter=100; total time=   3.2s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=6, max_iter=100; total time=   2.5s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=8, max_iter=100; total time=   3.4s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=8, max_iter=100; total time=   3.2s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=8, max_iter=100; total time=   3.6s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=8, max_iter=100; total time=   2.4s
# [CV] END l2_regularization=2, learning_rate=0.3, max_depth=8, max_iter=100; total time=   3.5s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.4s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.8s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.6s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=3, max_iter=100; total time=   1.0s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=4, max_iter=100; total time=   1.9s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=4, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.0s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.5s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=4, max_iter=100; total time=   2.3s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=6, max_iter=100; total time=   4.6s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=6, max_iter=100; total time=   5.2s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=6, max_iter=100; total time=   4.9s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=6, max_iter=100; total time=   4.4s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=6, max_iter=100; total time=   3.6s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=8, max_iter=100; total time=   5.2s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=8, max_iter=100; total time=  10.2s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=8, max_iter=100; total time=  26.0s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=8, max_iter=100; total time=  47.4s
# [CV] END l2_regularization=3, learning_rate=0.05, max_depth=8, max_iter=100; total time=  51.6s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=3, max_iter=100; total time=  14.9s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=3, max_iter=100; total time=  13.7s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=3, max_iter=100; total time=  11.1s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=3, max_iter=100; total time=  14.6s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=3, max_iter=100; total time=  12.8s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=4, max_iter=100; total time=  16.6s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=4, max_iter=100; total time=  13.0s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=4, max_iter=100; total time=  18.5s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=4, max_iter=100; total time=  12.2s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=4, max_iter=100; total time=  20.1s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=6, max_iter=100; total time=  19.9s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=6, max_iter=100; total time=  31.4s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=6, max_iter=100; total time=  34.5s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=6, max_iter=100; total time=  42.5s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=6, max_iter=100; total time=  32.9s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=8, max_iter=100; total time=  55.1s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=8, max_iter=100; total time=  56.5s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=8, max_iter=100; total time=  49.2s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=8, max_iter=100; total time=  55.5s
# [CV] END l2_regularization=3, learning_rate=0.1, max_depth=8, max_iter=100; total time=  48.5s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=3, max_iter=100; total time=  15.1s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=3, max_iter=100; total time=  11.4s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=3, max_iter=100; total time=  13.8s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=3, max_iter=100; total time=   9.9s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=3, max_iter=100; total time=  12.5s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=4, max_iter=100; total time=  15.8s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=4, max_iter=100; total time=  21.4s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=4, max_iter=100; total time=  18.8s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=4, max_iter=100; total time=  18.4s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=4, max_iter=100; total time=  20.8s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=6, max_iter=100; total time=  29.0s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=6, max_iter=100; total time=  16.2s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=6, max_iter=100; total time=   5.8s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=6, max_iter=100; total time=  13.5s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=6, max_iter=100; total time=  37.8s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=8, max_iter=100; total time=  45.0s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=8, max_iter=100; total time=  46.5s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=8, max_iter=100; total time=  47.1s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=8, max_iter=100; total time=   7.7s
# [CV] END l2_regularization=3, learning_rate=0.3, max_depth=8, max_iter=100; total time=   9.0s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=3, max_iter=100; total time=  14.2s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=3, max_iter=100; total time=  15.3s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=3, max_iter=100; total time=  14.7s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=3, max_iter=100; total time=  12.6s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=3, max_iter=100; total time=  15.4s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=4, max_iter=100; total time=  21.9s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=4, max_iter=100; total time=  21.5s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=4, max_iter=100; total time=  26.1s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=4, max_iter=100; total time=  23.7s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=4, max_iter=100; total time=  21.8s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=6, max_iter=100; total time=  48.0s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=6, max_iter=100; total time=  41.3s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=6, max_iter=100; total time=  39.7s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=6, max_iter=100; total time=  45.3s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=6, max_iter=100; total time=  48.7s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=8, max_iter=100; total time=  59.4s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=8, max_iter=100; total time=  55.5s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=8, max_iter=100; total time= 1.3min
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=8, max_iter=100; total time=  57.0s
# [CV] END l2_regularization=5, learning_rate=0.05, max_depth=8, max_iter=100; total time=  42.0s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=3, max_iter=100; total time=  10.6s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=3, max_iter=100; total time=   7.9s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=3, max_iter=100; total time=  11.7s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=3, max_iter=100; total time=   8.3s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=3, max_iter=100; total time=  13.4s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=4, max_iter=100; total time=  17.5s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=4, max_iter=100; total time=  19.9s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=4, max_iter=100; total time=  19.3s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=4, max_iter=100; total time=  16.1s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=4, max_iter=100; total time=  22.7s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=6, max_iter=100; total time=  32.5s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=6, max_iter=100; total time=  26.9s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=6, max_iter=100; total time=  36.5s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=6, max_iter=100; total time=  30.2s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=6, max_iter=100; total time=  19.5s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=8, max_iter=100; total time=  55.3s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=8, max_iter=100; total time=  51.7s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=8, max_iter=100; total time=  52.9s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=8, max_iter=100; total time=  20.8s
# [CV] END l2_regularization=5, learning_rate=0.1, max_depth=8, max_iter=100; total time=  16.8s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=3, max_iter=100; total time=   6.3s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=3, max_iter=100; total time=   9.1s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=3, max_iter=100; total time=   6.1s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=3, max_iter=100; total time=   7.3s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=3, max_iter=100; total time=  10.3s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=4, max_iter=100; total time=  17.0s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=4, max_iter=100; total time=  13.4s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=4, max_iter=100; total time=  11.9s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=4, max_iter=100; total time=  13.2s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=4, max_iter=100; total time=  14.3s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=6, max_iter=100; total time=  21.1s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=6, max_iter=100; total time=  18.5s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=6, max_iter=100; total time=  15.2s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=6, max_iter=100; total time=  14.6s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=6, max_iter=100; total time=  22.6s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=8, max_iter=100; total time=  22.9s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=8, max_iter=100; total time=  33.7s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=8, max_iter=100; total time=  29.9s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=8, max_iter=100; total time=  28.6s
# [CV] END l2_regularization=5, learning_rate=0.3, max_depth=8, max_iter=100; total time=  24.3s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=3, max_iter=100; total time=  11.8s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=3, max_iter=100; total time=   6.4s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=3, max_iter=100; total time=  11.1s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=3, max_iter=100; total time=   8.8s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=3, max_iter=100; total time=   9.9s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=4, max_iter=100; total time=  15.6s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=4, max_iter=100; total time=  14.4s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=4, max_iter=100; total time=  16.2s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=4, max_iter=100; total time=  11.9s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=4, max_iter=100; total time=  13.6s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=6, max_iter=100; total time=  30.1s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=6, max_iter=100; total time=  32.2s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=6, max_iter=100; total time=  31.7s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=6, max_iter=100; total time=  27.1s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=6, max_iter=100; total time=  19.2s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=8, max_iter=100; total time=  37.3s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=8, max_iter=100; total time=  34.9s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=8, max_iter=100; total time=  33.2s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=8, max_iter=100; total time=  40.4s
# [CV] END l2_regularization=10, learning_rate=0.05, max_depth=8, max_iter=100; total time=  36.2s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=3, max_iter=100; total time=  11.4s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=3, max_iter=100; total time=   6.2s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=3, max_iter=100; total time=  11.7s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=3, max_iter=100; total time=  10.9s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=3, max_iter=100; total time=   6.8s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=4, max_iter=100; total time=   3.0s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=4, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=4, max_iter=100; total time=   0.6s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=6, max_iter=100; total time=   0.5s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=6, max_iter=100; total time=   1.2s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=6, max_iter=100; total time=   0.6s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=6, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=6, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=8, max_iter=100; total time=   0.4s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=8, max_iter=100; total time=   0.7s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=8, max_iter=100; total time=   0.5s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=8, max_iter=100; total time=   0.4s
# [CV] END l2_regularization=10, learning_rate=0.1, max_depth=8, max_iter=100; total time=   0.4s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.1s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.1s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=3, max_iter=100; total time=   0.1s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=4, max_iter=100; total time=   0.1s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=4, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=6, max_iter=100; total time=   0.4s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=6, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=6, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=6, max_iter=100; total time=   0.3s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=6, max_iter=100; total time=   0.2s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=8, max_iter=100; total time=   0.6s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=8, max_iter=100; total time=   0.6s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=8, max_iter=100; total time=   0.9s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=8, max_iter=100; total time=   0.7s
# [CV] END l2_regularization=10, learning_rate=0.3, max_depth=8, max_iter=100; total time=   0.3s
# Best parameters: {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 4, 'max_iter': 100}
# Best RMSE: 27020.600938145195

# %%
model = HistGradientBoostingRegressor(categorical_features='from_dtype', **grid_search.best_params_)
model.fit(dataset_df, y)
test_file_path = "data/house-prices/test.csv"
test_data = pd.read_csv(test_file_path)
ids = test_data.pop('Id')

test_data = prepare_dataset(test_data, False)
sample_submission_df = pd.read_csv('data/house-prices/sample_submission.csv')
sample_submission_df['SalePrice'] = model.predict(test_data)
sample_submission_df.to_csv('working/hist-cv.csv', index=False)
sample_submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  128149.981297
# 1  1462  157240.705910
# 2  1463  182599.478059
# 3  1464  197312.203554
# 4  1465  199533.499288
