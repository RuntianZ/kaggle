# %%
import pandas as pd
from catboost import CatBoostRegressor, Pool, cv
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
def prepare_dataset(df):
    # For categorical features, replace NA with "Missing"
    categorical_columns = df.select_dtypes(include=['object']).columns
    for key in categorical_columns:
        df[key] = df[key].astype('category').cat.add_categories("Missing").fillna("Missing")
    categorical_columns = df.select_dtypes(include=['category']).columns
    return df, categorical_columns

# %%
train_file_path = "data/house-prices/train.csv"
dataset_df = pd.read_csv(train_file_path)
print("Full train dataset shape is {}".format(dataset_df.shape))
dataset_df.head(3)
# Out:
# Full train dataset shape is (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
dataset_df, categorical_columns = prepare_dataset(dataset_df)
dataset_df[categorical_columns].head(10)
# Out:
#   MSZoning Street    Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave  Missing      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave  Missing      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave  Missing      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave  Missing      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave  Missing      IR1         Lvl    AllPub       FR2       Gtl
# 5       RL   Pave  Missing      IR1         Lvl    AllPub    Inside       Gtl
# 6       RL   Pave  Missing      Reg         Lvl    AllPub    Inside       Gtl
# 7       RL   Pave  Missing      IR1         Lvl    AllPub    Corner       Gtl
# 8       RM   Pave  Missing      Reg         Lvl    AllPub    Inside       Gtl
# 9       RL   Pave  Missing      Reg         Lvl    AllPub    Corner       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
# 5      Mitchel       Norm  ...     Attchd          Unf         TA         TA
# 6      Somerst       Norm  ...     Attchd          RFn         TA         TA
# 7       NWAmes       PosN  ...     Attchd          RFn         TA         TA
# 8      OldTown     Artery  ...     Detchd          Unf         Fa         TA
# 9      BrkSide     Artery  ...     Attchd          RFn         Gd         TA
#
#   PavedDrive   PoolQC    Fence MiscFeature SaleType SaleCondition
# 0          Y  Missing  Missing     Missing       WD        Normal
# 1          Y  Missing  Missing     Missing       WD        Normal
# 2          Y  Missing  Missing     Missing       WD        Normal
# 3          Y  Missing  Missing     Missing       WD       Abnorml
# 4          Y  Missing  Missing     Missing       WD        Normal
# 5          Y  Missing    MnPrv        Shed       WD        Normal
# 6          Y  Missing  Missing     Missing       WD        Normal
# 7          Y  Missing  Missing        Shed       WD        Normal
# 8          Y  Missing  Missing     Missing       WD       Abnorml
# 9          Y  Missing  Missing     Missing       WD        Normal
#
# [10 rows x 43 columns]

# %%
# Prepare dataset
target_column = 'SalePrice'
y = dataset_df.pop(target_column)
X = dataset_df.drop('Id', axis=1)

# %%
# Define model parameters
params = {
    'iterations': 1000,
    'depth': 6,
    'loss_function': 'RMSE',
    'verbose': 200,
    'early_stopping_rounds': 50
}

# Cross-validation parameters
cv_params = {
    'fold_count': 5,     # Number of folds in CV
    'shuffle': True,     # Shuffle data before splitting into batches
    'partition_random_seed': 0,  # Random seed for shuffling
    'stratified': False,  # Whether to perform stratified sampling
    'plot': True         # Whether to plot curve of metrics during training
}

# %%
# Perform cross-validation
pool_data = Pool(data=X, label=y, cat_features=categorical_columns.to_list())
cv_results = cv(pool=pool_data, params=params, fold_count=cv_params['fold_count'],
                shuffle=cv_params['shuffle'], partition_random_seed=cv_params['partition_random_seed'],
                stratified=cv_params['stratified'], plot=cv_params['plot'])

# Output results
print(cv_results)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
# 0:	learn: 191655.8001431	test: 194801.4789916	best: 194801.4789916 (0)	total: 138ms	remaining: 2m 17s
# 200:	learn: 21665.9476024	test: 29790.6289848	best: 29790.6289848 (200)	total: 15.8s	remaining: 1m 2s
# 400:	learn: 16166.1062903	test: 26405.8589363	best: 26405.8589363 (400)	total: 31.8s	remaining: 47.5s
# 600:	learn: 13465.6417160	test: 25652.3909561	best: 25652.3909561 (600)	total: 48.3s	remaining: 32.1s
# 800:	learn: 11410.6290921	test: 25326.0068387	best: 25326.0068387 (800)	total: 1m 4s	remaining: 16.1s
# 999:	learn: 9915.3679869	test: 25128.0093982	best: 25125.7908877 (996)	total: 1m 21s	remaining: 0us
#
# bestTest = 25125.79089
# bestIteration = 996
#
# Training on fold [1/5]
# 0:	learn: 191961.4288738	test: 194413.9678392	best: 194413.9678392 (0)	total: 88ms	remaining: 1m 27s
# 200:	learn: 20629.1848262	test: 27029.1179947	best: 27029.1179947 (200)	total: 15.6s	remaining: 1m 1s
# 400:	learn: 14718.5804019	test: 25678.7221359	best: 25678.7221359 (400)	total: 32.3s	remaining: 48.2s
# 600:	learn: 12512.4598288	test: 25166.9157815	best: 25164.5069570 (596)	total: 48.8s	remaining: 32.4s
# 800:	learn: 11076.1542008	test: 24836.9421159	best: 24836.9421159 (800)	total: 1m 5s	remaining: 16.3s
# 999:	learn: 9851.9826811	test: 24644.5046961	best: 24642.9444361 (992)	total: 1m 22s	remaining: 0us
#
# bestTest = 24642.94444
# bestIteration = 992
#
# Training on fold [2/5]
# 0:	learn: 191410.2080038	test: 195973.5569836	best: 195973.5569836 (0)	total: 78ms	remaining: 1m 17s
# 200:	learn: 20972.2458820	test: 40168.6519486	best: 40052.3262037 (192)	total: 16s	remaining: 1m 3s
#
# bestTest = 39990.9579
# bestIteration = 240
#
# Training on fold [3/5]
# 0:	learn: 194263.5022694	test: 184367.1815300	best: 184367.1815300 (0)	total: 83.9ms	remaining: 1m 23s
# 200:	learn: 21986.5617340	test: 26640.3857353	best: 26640.3857353 (200)	total: 16.2s	remaining: 1m 4s
# 400:	learn: 16234.1872575	test: 24320.1184534	best: 24304.0558321 (398)	total: 32.9s	remaining: 49.2s
# 600:	learn: 13911.1945851	test: 23826.2220365	best: 23817.6023145 (593)	total: 50.5s	remaining: 33.5s
#
# bestTest = 23674.30052
# bestIteration = 712
#
# Training on fold [4/5]
# 0:	learn: 192800.2913428	test: 192560.0765449	best: 192560.0765449 (0)	total: 104ms	remaining: 1m 43s
# 200:	learn: 22001.4607081	test: 23616.0589744	best: 23616.0589744 (200)	total: 16.2s	remaining: 1m 4s
# 400:	learn: 16401.0689234	test: 21218.9737567	best: 21218.9737567 (400)	total: 33.3s	remaining: 49.8s
# 600:	learn: 14225.2297974	test: 20545.4015205	best: 20542.8378994 (596)	total: 50.5s	remaining: 33.5s
# 800:	learn: 12428.4380014	test: 20350.8524397	best: 20349.8221371 (799)	total: 1m 8s	remaining: 16.9s
#
# bestTest = 20327.4233
# bestIteration = 866
#
#      iterations  test-RMSE-mean  test-RMSE-std  train-RMSE-mean  \
# 0             0   192423.252378    4667.509267    192418.246127
# 1             1   187487.281281    4609.749220    187422.111177
# 2             2   182768.746561    4658.550575    182597.716293
# 3             3   178107.020367    4647.961798    177943.981716
# 4             4   173733.445966    4814.283635    173404.659320
# ..          ...             ...            ...              ...
# 995         995    26774.976343    7650.239942     12430.987480
# 996         996    26774.891144    7650.255502     12430.113475
# 997         997    26774.995610    7650.230038     12427.977695
# 998         998    26774.859376    7650.277592     12427.789663
# 999         999    26774.919112    7650.280669     12424.300755
#
#      train-RMSE-std
# 0       1157.267851
# 1       1220.728755
# 2       1167.831599
# 3       1143.400268
# 4       1145.436544
# ..              ...
# 995     3462.790148
# 996     3463.581957
# 997     3465.530520
# 998     3465.702081
# 999     3468.900962
#
# [1000 rows x 5 columns]

# %%
# Grid Search
from sklearn.model_selection import GridSearchCV

# Define the model
model = CatBoostRegressor()

# Set up the parameter grid
param_grid = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'iterations': [100, 500, 1000]
}

# Configure GridSearchCV
# When cv=None, default is 5-fold cross validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           cv=None, scoring='neg_mean_squared_error', verbose=2)

# Fit GridSearchCV
grid_search.fit(X, y, cat_features=categorical_columns.to_list(), verbose=200)

# Best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best RMSE:", (-grid_search.best_score_) ** 0.5)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# 0:	learn: 80152.8606922	total: 17ms	remaining: 1.68s
# 99:	learn: 48961.3040980	total: 629ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.01; total time=   0.7s
# 0:	learn: 78514.9687236	total: 19.6ms	remaining: 1.94s
# 99:	learn: 47567.0671572	total: 736ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.01; total time=   0.8s
# 0:	learn: 76877.3102851	total: 22ms	remaining: 2.18s
# 99:	learn: 46559.0335290	total: 722ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.01; total time=   0.8s
# 0:	learn: 80713.0572734	total: 21.8ms	remaining: 2.16s
# 99:	learn: 48921.5965406	total: 812ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.01; total time=   0.9s
# 0:	learn: 78286.3423412	total: 21.6ms	remaining: 2.14s
# 99:	learn: 46952.6925053	total: 822ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.01; total time=   0.9s
# 0:	learn: 78290.0941326	total: 22.2ms	remaining: 2.2s
# 99:	learn: 24210.4372209	total: 864ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.05; total time=   0.9s
# 0:	learn: 76628.9589755	total: 21.5ms	remaining: 2.13s
# 99:	learn: 23884.2049746	total: 693ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.05; total time=   0.7s
# 0:	learn: 74956.0234553	total: 16.2ms	remaining: 1.6s
# 99:	learn: 24818.8889959	total: 620ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.05; total time=   0.7s
# 0:	learn: 78675.5432372	total: 22ms	remaining: 2.17s
# 99:	learn: 25073.4705087	total: 807ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.05; total time=   0.8s
# 0:	learn: 76321.4571383	total: 16.6ms	remaining: 1.64s
# 99:	learn: 24035.8421020	total: 623ms	remaining: 0us
# [CV] END ........depth=4, iterations=100, learning_rate=0.05; total time=   0.7s
# 0:	learn: 76007.1786931	total: 18.3ms	remaining: 1.82s
# 99:	learn: 20080.4909153	total: 622ms	remaining: 0us
# [CV] END .........depth=4, iterations=100, learning_rate=0.1; total time=   0.7s
# 0:	learn: 74310.0094449	total: 17.6ms	remaining: 1.75s
# 99:	learn: 20162.7601327	total: 629ms	remaining: 0us
# [CV] END .........depth=4, iterations=100, learning_rate=0.1; total time=   0.7s
# 0:	learn: 72595.1932847	total: 21.2ms	remaining: 2.1s
# 99:	learn: 19096.5007740	total: 787ms	remaining: 0us
# [CV] END .........depth=4, iterations=100, learning_rate=0.1; total time=   0.8s
# 0:	learn: 76168.9301894	total: 20.9ms	remaining: 2.07s
# 99:	learn: 20404.5228890	total: 762ms	remaining: 0us
# [CV] END .........depth=4, iterations=100, learning_rate=0.1; total time=   0.8s
# 0:	learn: 73907.4529695	total: 16.6ms	remaining: 1.64s
# 99:	learn: 19538.2479378	total: 615ms	remaining: 0us
# [CV] END .........depth=4, iterations=100, learning_rate=0.1; total time=   0.6s
# 0:	learn: 80119.7995807	total: 53ms	remaining: 26.5s
# 200:	learn: 35869.4851778	total: 8.01s	remaining: 11.9s
# 400:	learn: 26814.4223705	total: 15.9s	remaining: 3.92s
# 499:	learn: 24450.0976818	total: 20.1s	remaining: 0us
# [CV] END ........depth=4, iterations=500, learning_rate=0.01; total time=  20.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 20
#      16 grid_search = GridSearchCV(estimator=model, param_grid=param_grid,
#      17                            cv=None, scoring='neg_mean_squared_error', verbose=2)
#      19 # Fit GridSearchCV
# ---> 20 grid_search.fit(X, y, cat_features=categorical_columns.to_list(), verbose=200)
#      22 # Best parameters and best score
#      23 print("Best parameters:", grid_search.best_params_)
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/catboost/core.py:5827, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5824 if 'loss_function' in params:
#    5825     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5827 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5828                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5829                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5830                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/catboost/core.py:2385, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2382 if y is None and not isinstance(X, PATH_TYPES + (Pool,)):
#    2383     raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
# -> 2385 train_params = self._prepare_train_params(
#    2386     X=X, y=y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features,
#    2387     pairs=pairs, sample_weight=sample_weight, group_id=group_id, group_weight=group_weight,
#    2388     subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline, use_best_model=use_best_model,
#    2389     eval_set=eval_set, verbose=verbose, logging_level=logging_level, plot=plot, plot_file=plot_file,
#    2390     column_description=column_description, verbose_eval=verbose_eval, metric_period=metric_period,
#    2391     silent=silent, early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    2392     snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
#    2393     callbacks=callbacks
#    2394 )
#    2395 params = train_params["params"]
#    2396 train_pool = train_params["train_pool"]
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/catboost/core.py:2265, in CatBoost._prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    2262 text_features = _process_feature_indices(text_features, X, params, 'text_features')
#    2263 embedding_features = _process_feature_indices(embedding_features, X, params, 'embedding_features')
# -> 2265 train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#    2266                                sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
#    2267                                baseline, column_description)
#    2268 if train_pool.is_empty_:
#    2269     raise CatBoostError("X is empty.")
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/catboost/core.py:1503, in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1501     if y is None:
#    1502         raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
# -> 1503     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#    1504                       group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#    1505 return train_pool
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/catboost/core.py:848, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr, data_can_be_none)
#     842         if isinstance(feature_names, PATH_TYPES):
#     843             raise CatBoostError(
#     844                 "feature_names must be None or have non-string type when the pool is created from "
#     845                 "python objects."
#     846             )
# --> 848         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     849                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     850 elif not data_can_be_none:
#     851     raise CatBoostError("'data' parameter can't be None")
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/catboost/core.py:1481, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1479 if feature_tags is not None:
#    1480     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1481 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1482                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:4159, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4209, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4025, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2905, in _catboost._set_features_order_data_pd_data_frame()
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:1488, in DataFrame.items(self)
#    1486 if self.columns.is_unique and hasattr(self, "_item_cache"):
#    1487     for k in self.columns:
# -> 1488         yield k, self._get_item_cache(k)
#    1489 else:
#    1490     for i, k in enumerate(self.columns):
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:4627, in DataFrame._get_item_cache(self, item)
#    4622 if res is None:
#    4623     # All places that call _get_item_cache have unique columns,
#    4624     #  pending resolution of GH#33047
#    4626     loc = self.columns.get_loc(item)
# -> 4627     res = self._ixs(loc, axis=1)
#    4629     cache[item] = res
#    4631     # for a chain
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:3998, in DataFrame._ixs(self, i, axis)
#    3994 # icol
#    3995 else:
#    3996     label = self.columns[i]
# -> 3998     col_mgr = self._mgr.iget(i)
#    3999     result = self._box_col_values(col_mgr, i)
#    4001     # this is a cached value, mark it so
#
# File /usr1/rzhai/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/internals/managers.py:1020, in BlockManager.iget(self, i, track_ref)
#    1017 values = block.iget(self.blklocs[i])
#    1019 # shortcut for select a single-dim from a 2-dim BM
# -> 1020 bp = BlockPlacement(slice(0, len(values)))
#    1021 nb = type(block)(
#    1022     values, placement=bp, ndim=1, refs=block.refs if track_ref else None
#    1023 )
#    1024 return SingleBlockManager(nb, self.axes[1])
#
# KeyboardInterrupt:

# %%
# Initialize CatBoostRegressor
model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.1,
    depth=6,
    cat_features=categorical_columns.to_list(),
    verbose=200
)

# Train the model
model.fit(X_train, y_train)
# Out:
# 0:	learn: 72294.6354378	total: 130ms	remaining: 2m 10s
# 200:	learn: 11975.1591565	total: 13.2s	remaining: 52.3s
# 400:	learn: 7848.5657342	total: 26.4s	remaining: 39.5s
# 600:	learn: 5794.8592565	total: 39.7s	remaining: 26.3s
# 800:	learn: 4391.0635829	total: 53s	remaining: 13.2s
# 999:	learn: 3449.6115972	total: 1m 6s	remaining: 0us

# %%
# Make predictions
predictions = model.predict(X_test)

# Calculate MSE
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 710509538.7781416

# %%
feature_importances = model.get_feature_importance()
print(pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances}).sort_values(by='Importance', ascending=False))
# Out:
#          Feature  Importance
# 16   OverallQual   21.711074
# 45     GrLivArea   12.864158
# 37   TotalBsmtSF    5.271276
# 60    GarageCars    4.888689
# 33    BsmtFinSF1    4.663881
# ..           ...         ...
# 38       Heating    0.007136
# 44  LowQualFinSF    0.002441
# 74       MiscVal    0.000880
# 8      Utilities    0.000245
# 4         Street    0.000208
#
# [79 rows x 2 columns]

# %%
test_file_path = "data/house-prices/test.csv"
test_data = pd.read_csv(test_file_path)
ids = test_data.pop('Id')

categorical_columns = test_data.select_dtypes(include=['object']).columns
print(categorical_columns)
for key in categorical_columns:
    test_data[key] = test_data[key].astype('category').cat.add_categories("Missing").fillna("Missing")
test_data.head(3)
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          20       RH         80.0    11622   Pave  Missing      Reg
# 1          20       RL         81.0    14267   Pave  Missing      IR1
# 2          60       RL         74.0    13830   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea   PoolQC    Fence  \
# 0         Lvl    AllPub    Inside  ...         120        0  Missing    MnPrv
# 1         Lvl    AllPub    Corner  ...           0        0  Missing  Missing
# 2         Lvl    AllPub    Inside  ...           0        0  Missing    MnPrv
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0     Missing       0       6    2010        WD         Normal
# 1        Gar2   12500       6    2010        WD         Normal
# 2     Missing       0       3    2010        WD         Normal
#
# [3 rows x 79 columns]

# %%
preds = model.predict(test_data)
output = pd.DataFrame({'Id': ids,
                       'SalePrice': preds.squeeze()})

output.head()
# Out:
#      Id      SalePrice
# 0  1461  122419.622910
# 1  1462  164402.590247
# 2  1463  190268.284650
# 3  1464  187815.405724
# 4  1465  197764.470962

# %%
sample_submission_df = pd.read_csv('data/house-prices/sample_submission.csv')
sample_submission_df['SalePrice'] = model.predict(test_data)
sample_submission_df.to_csv('working/catboost.csv', index=False)
sample_submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  122419.622910
# 1  1462  164402.590247
# 2  1463  190268.284650
# 3  1464  187815.405724
# 4  1465  197764.470962
